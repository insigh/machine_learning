# %%
import graphlab

# %%
image_train=graphlab.SFrame('image_train_data/')
image_test=graphlab.SFrame('image_test_data/')
graphlab.canvas.set_target('ipynb')

# %%
#for item in ['dog','cat','automobile','bird']
dog_data=image_train[image_train['label']=='dog']
cat_data=image_train[image_train['label']=='cat']
automobile_data=image_train[image_train['label']=='automobile']
bird_data=image_train[image_train['label']=='bird']

# %%
dog_model=graphlab.nearest_neighbors.create(dog_data,features=['deep_features'],
                                           label='id')
# Out:
# Starting brute force nearest neighbors model training.

# %%
cat_model=graphlab.nearest_neighbors.create(cat_data,features=['deep_features'],
                                           label='id')
# Out:
# Starting brute force nearest neighbors model training.

# %%
automobile_model=graphlab.nearest_neighbors.create(automobile_data,features=['deep_features'],
                                           label='id')
# Out:
# Starting brute force nearest neighbors model training.

# %%
bird_model=graphlab.nearest_neighbors.create(bird_data,features=['deep_features'],
                                           label='id')
# Out:
# Starting brute force nearest neighbors model training.

# %%
image_test_cat=image_test[image_test['label']=='cat']
image_test_dog=image_test[image_test['label']=='dog']
image_test_automobile=image_test[image_test['label']=='automobile']
image_test_bird=image_test[image_test['label']=='bird']

# %%
image_test_automobile['image'][0:1].show()

# %%
cat_model.query(image_test[0:1])
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.196464    | 8ms          |
# | Done         |         | 100         | 68ms         |
# +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	int
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+---------------+------+
# | query_label | reference_label |    distance   | rank |
# +-------------+-----------------+---------------+------+
# |      0      |      16289      |  34.623719208 |  1   |
# |      0      |      45646      | 36.0068799284 |  2   |
# |      0      |      32139      | 36.5200813436 |  3   |
# |      0      |      25713      | 36.7548502521 |  4   |
# |      0      |       331       | 36.8731228168 |  5   |
# +-------------+-----------------+---------------+------+
# [5 rows x 4 columns]

# %%
cat_data[cat_data['id']==16289]['image'].show()

# %%
dog_model.query(image_test[0:1])
# Out:
# Starting pairwise querying.
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 0            | 1       | 0.196464    | 12.006ms     |
# | Done         |         | 100         | 84ms         |
# +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	int
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+---------------+------+
# | query_label | reference_label |    distance   | rank |
# +-------------+-----------------+---------------+------+
# |      0      |      16976      | 37.4642628784 |  1   |
# |      0      |      13387      | 37.5666832169 |  2   |
# |      0      |      35867      | 37.6047267079 |  3   |
# |      0      |      44603      | 37.7065585153 |  4   |
# |      0      |       6094      | 38.5113254907 |  5   |
# +-------------+-----------------+---------------+------+
# [5 rows x 4 columns]

# %%
dog_data[dog_data['id']==16976]['image'].show()

# %%
dog_cat_neighbors=cat_model.query(image_test_dog,k=1)
dog_dog_neighbors=dog_model.query(image_test_dog,k=1)
dog_automobie_neighbors=automobile_model.query(image_test_dog,k=1)
dog_bird_neighbors=bird_model.query(image_test_dog,k=1)
# Out:
# Starting blockwise querying.
# max rows per data block: 4348
# number of reference data blocks: 4
# number of query data blocks: 1
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 1000         | 127000  | 24.9509     | 346.985ms    |
# | Done         | 509000  | 100         | 399.123ms    |
# +--------------+---------+-------------+--------------+
# Starting blockwise querying.
# max rows per data block: 4348
# number of reference data blocks: 4
# number of query data blocks: 1
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 1000         | 127000  | 24.9509     | 396.817ms    |
# | Done         | 509000  | 100         | 425.896ms    |
# +--------------+---------+-------------+--------------+
# Starting blockwise querying.
# max rows per data block: 4348
# number of reference data blocks: 4
# number of query data blocks: 1
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 1000         | 127000  | 24.9509     | 381.449ms    |
# | Done         | 509000  | 100         | 403.507ms    |
# +--------------+---------+-------------+--------------+
# Starting blockwise querying.
# max rows per data block: 4348
# number of reference data blocks: 4
# number of query data blocks: 1
# +--------------+---------+-------------+--------------+
# | Query points | # Pairs | % Complete. | Elapsed Time |
# +--------------+---------+-------------+--------------+
# | 1000         | 120000  | 25.1046     | 533.417ms    |
# | Done         | 478000  | 100         | 582.549ms    |
# +--------------+---------+-------------+--------------+

# %%
dog_cat_neighbors.head()
# Out:
# Columns:
# 	query_label	int
# 	reference_label	int
# 	distance	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +-------------+-----------------+---------------+------+
# | query_label | reference_label |    distance   | rank |
# +-------------+-----------------+---------------+------+
# |      0      |        33       | 36.4196077068 |  1   |
# |      1      |      30606      | 38.8353268874 |  1   |
# |      2      |       5545      | 36.9763410854 |  1   |
# |      3      |      19631      | 34.5750072914 |  1   |
# |      4      |       7493      |  34.778824791 |  1   |
# |      5      |      47044      | 35.1171578292 |  1   |
# |      6      |      13918      | 40.6095830913 |  1   |
# |      7      |      10981      | 39.9036867306 |  1   |
# |      8      |      45456      | 38.0674700168 |  1   |
# |      9      |      44673      | 42.7258732951 |  1   |
# +-------------+-----------------+---------------+------+
# [10 rows x 4 columns]

# %%
dog_neighbors=graphlab.SFrame({'dog-automible':dog_automobie_neighbors['distance'],
                               'dog-bird':dog_bird_neighbors['distance'],
                               'dog-cat':dog_cat_neighbors['distance'],
                               'dog-dog':dog_dog_neighbors['distance']
                              })

# %%
dog_neighbors.head()
# Out:
# Columns:
# 	dog-automible	float
# 	dog-bird	float
# 	dog-cat	float
# 	dog-dog	float
#
# Rows: 10
#
# Data:
# +---------------+---------------+---------------+---------------+
# | dog-automible |    dog-bird   |    dog-cat    |    dog-dog    |
# +---------------+---------------+---------------+---------------+
# | 41.9579761457 | 41.7538647304 | 36.4196077068 | 33.4773590373 |
# | 46.0021331807 | 41.3382958925 | 38.8353268874 | 32.8458495684 |
# | 42.9462290692 | 38.6157590853 | 36.9763410854 | 35.0397073189 |
# | 41.6866060048 | 37.0892269954 | 34.5750072914 | 33.9010327697 |
# | 39.2269664935 |  38.272288694 |  34.778824791 | 37.4849250909 |
# | 40.5845117698 | 39.1462089236 | 35.1171578292 |  34.945165344 |
# | 45.1067352961 |  40.523040106 | 40.6095830913 | 39.0957278345 |
# | 41.3221140974 | 38.1947918393 | 39.9036867306 | 37.7696131032 |
# | 41.8244654995 | 40.1567131661 | 38.0674700168 | 35.1089144603 |
# | 45.4976929401 | 45.5597962603 | 42.7258732951 | 43.2422832585 |
# +---------------+---------------+---------------+---------------+
# [10 rows x 4 columns]

# %%
def is_dog_correct(row):
    return row['dog-dog']<=row['dog-automible'] and row['dog-dog']<=row['dog-bird'] and row['dog-dog']<=row['dog-cat']

# %%
dog_neighbors.apply(is_dog_correct).sum()
# Out:
# 678L

# %%
len(dog_neighbors)
# Out:
# 1000
